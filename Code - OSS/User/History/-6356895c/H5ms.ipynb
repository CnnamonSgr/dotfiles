# %%
rown=x^2+3*x+2

show(rown)

pochodna = diff(rown, x)

show(rown.diff())

show(plot(rown, x, -10, 10, ymax=110, ymin=-20, axes_labels=['$x$', '$y$'], legend_label='Równanie', color='red') + plot(pochodna, x, -10, 10, ymax=110, ymin=-20, axes_labels=['$x$', '$y$'], legend_label='Pochodna', color='green') + point((-3/2, -1/4), size=25, color='magenta'))

show(solve(pochodna==0, x))
show(rown(x=-3/2))


p1 = plot(sin(x), -2*pi, 2*pi, figsize=3, color='blue')
p2 = plot(cos(x), -2*pi, 2*pi, figsize=3, color='green')
p3 = plot(sin(x^2), -2*pi, 2*pi, figsize=3, color='orange')
p4 = plot(cos(x^2), -2*pi, 2*pi, figsize=3, color='red')

graphics_array(((p1, p2), (p3, p4)))
# Out:
# x^2 + 3*x + 2
# 2*x + 3
# Graphics object consisting of 3 graphics primitives
# [x == (-3/2)]
# -1/4
# Graphics Array of size 2 x 2

# %%
y = - (10^2 + (5*x)*(6*x))-25*x + 1000 - sqrt(5) 
show(y) 
print(1) 
show(plot(y,x,-20,20,ymin = -2000,ymax = 2000,axes_labels = ['$x$','$y$'])) 
print(2) 
show(solve(y == 0 ,x)) 
print(3) 
row2 = y 
poch2 = row2.diff() 
show(plot(row2,x,-20,20,ymin = -2000,ymax = 2000,axes_labels = ['$x$','$y$']) + plot(poch2,x,-20,20,ymin = -2000,ymax = 2000,axes_labels = ['$x$','$y$'])+point((-5/12,902.972265355834))) 
solve(poch2 == 0,x) 
print(row2(x=(-5/12)).n())
# Out:
# -30*x^2 - 25*x - sqrt(5) + 900
# 1
# Graphics object consisting of 1 graphics primitive
# 2
# [x == -1/60*sqrt(-120*sqrt(5) + 108625) - 5/12, x == 1/60*sqrt(-120*sqrt(5) + 108625) - 5/12]
# 3
# Graphics object consisting of 3 graphics primitives
# 902.972265355834
